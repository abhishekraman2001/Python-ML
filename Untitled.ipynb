# %%
import os
os.chdir(r'C:\Users\abhis\OneDrive\Desktop\DataScience\ML-Edurekha\W2\Data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abhis\\OneDrive\\Desktop\\DataScience\\ML-Edurekha\\W2\\Data'

# %%
import pandas as pd

# %%
df = pd.read_csv('AllCountries.csv',  nrows=10)

# %%
x = df.iloc[:10,1:6].values

# %%
df
# Out:
#                Country  LandArea  Population      GDP  Rural  Internet  \
# 0          Afghanistan    652.86      30.552    665.0   74.1       5.9
# 1              Albania     27.40       2.897   4460.0   44.6      60.1
# 2              Algeria   2381.74      39.208   5361.0   30.5      16.5
# 3       American Samoa      0.20       0.055      NaN   12.7       NaN
# 4              Andorra      0.47       0.079      NaN   13.8      94.0
# 5               Angola   1246.70      21.472   5783.0   57.5      19.1
# 6  Antigua and Barbuda      0.44       0.090  13342.0   75.4      63.4
# 7            Argentina   2736.69      41.446  14715.0    8.5      59.9
# 8              Armenia     28.47       2.977   3505.0   37.0      46.3
# 9                Aruba      0.18       0.103      NaN   57.9      78.9
#
#    BirthRate  DeathRate  ElderlyPop  LifeExpectancy  FemaleLabor  Unemployment
# 0       34.1        7.8         2.3            60.9         16.2           NaN
# ...

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3-q1

# %%
q1
# Out:
# LandArea             0.44750
# Population           0.09325
# GDP               3982.50000
# Rural               17.97500
# Internet            19.10000
# BirthRate           13.50000
# DeathRate            6.70000
# ElderlyPop           4.05000
# LifeExpectancy      68.47500
# FemaleLabor         25.07500
# Unemployment         9.10000
# Name: 0.25, dtype: float64

# %%
q3
# Out:
# LandArea          1098.240
# Population          28.282
# GDP               9562.500
# Rural               57.800
# Internet            63.400
# BirthRate           26.750
# DeathRate            8.475
# ElderlyPop          10.750
# LifeExpectancy      75.900
# FemaleLabor         57.575
# Unemployment        12.200
# Name: 0.75, dtype: float64

# %%
IQR
# Out:
# LandArea          1097.79250
# Population          28.18875
# GDP               5580.00000
# Rural               39.82500
# Internet            44.30000
# BirthRate           13.25000
# DeathRate            1.77500
# ElderlyPop           6.70000
# LifeExpectancy       7.42500
# FemaleLabor         32.50000
# Unemployment         3.10000
# dtype: float64

# %%
df[~((df<(q1-1.5*IQR))| (df> (q3+1.5*IQR))).any(axis=1)]
# Out:
#                Country  LandArea  Population      GDP  Rural  Internet  \
# 0          Afghanistan    652.86      30.552    665.0   74.1       5.9
# 1              Albania     27.40       2.897   4460.0   44.6      60.1
# 2              Algeria   2381.74      39.208   5361.0   30.5      16.5
# 3       American Samoa      0.20       0.055      NaN   12.7       NaN
# 4              Andorra      0.47       0.079      NaN   13.8      94.0
# 6  Antigua and Barbuda      0.44       0.090  13342.0   75.4      63.4
# 7            Argentina   2736.69      41.446  14715.0    8.5      59.9
# 8              Armenia     28.47       2.977   3505.0   37.0      46.3
# 9                Aruba      0.18       0.103      NaN   57.9      78.9
#
#    BirthRate  DeathRate  ElderlyPop  LifeExpectancy  FemaleLabor  Unemployment
# 0       34.1        7.8         2.3            60.9         16.2           NaN
# 1       12.9        6.9        10.7            77.5         51.7          13.4
# ...

# %%
def outlier_treatment(dataframe):
    Q1 = dataframe.quantile(0.25)
    Q3 = dataframe.quantile(0.75)
    IQR = Q3-Q1
    df_rem_out = dataframe[~((dataframe<(Q1-1.5*IQR))| (dataframe> (Q3+1.5*IQR))).any(axis=1)]
    return df_rem_out

# %%
outlier_treatment(df)
# Out:
#                Country  LandArea  Population      GDP  Rural  Internet  \
# 0          Afghanistan    652.86      30.552    665.0   74.1       5.9
# 1              Albania     27.40       2.897   4460.0   44.6      60.1
# 2              Algeria   2381.74      39.208   5361.0   30.5      16.5
# 3       American Samoa      0.20       0.055      NaN   12.7       NaN
# 4              Andorra      0.47       0.079      NaN   13.8      94.0
# 6  Antigua and Barbuda      0.44       0.090  13342.0   75.4      63.4
# 7            Argentina   2736.69      41.446  14715.0    8.5      59.9
# 8              Armenia     28.47       2.977   3505.0   37.0      46.3
# 9                Aruba      0.18       0.103      NaN   57.9      78.9
#
#    BirthRate  DeathRate  ElderlyPop  LifeExpectancy  FemaleLabor  Unemployment
# 0       34.1        7.8         2.3            60.9         16.2           NaN
# 1       12.9        6.9        10.7            77.5         51.7          13.4
# ...
